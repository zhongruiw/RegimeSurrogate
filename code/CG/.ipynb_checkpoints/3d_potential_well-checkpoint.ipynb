# %%
import numpy as np
from scipy.integrate import odeint
import h5py
from tqdm import tqdm

def U(v):
    Ax = 1.05
    Ay = 1.1
    Az = 1.15
    x, y, z = v
    return (x - Ax)**2 * (x + Ax)**2 + (y - Ay)**2 * (y + Ay)**2 + (z - Az)**2 * (z + Az)**2

def force(v, t):
    x, y, z = v
    dxdt = 2*(-1.05+x)**2*(1.05+x)+2*(-1.05+x)*(1.05+x)**2
    dydt = 2*(-1.1+y)**2*(1.1+y)+2*(-1.1+y)*(1.1+y)**2
    dzdt = 2*(-1.15+z)**2*(1.15+z)+2*(-1.15+z)*(1.15+z)**2
    return [-dxdt,-dydt,-dzdt]

def potential_data(timesteps, dt, res, eps):
    x_f = np.zeros((3, timesteps))
    xOld = np.zeros(3)
    
    for i in tqdm(range(1, timesteps)):
        xOld = x_f[:, i-1]
        sol = odeint(force, xOld, np.array([0, dt]))
        xOld = sol[-1,:]
        noise = np.random.randn(3)
        x_f[:, i] = xOld + eps * np.sqrt(dt) * noise

    L2 = timesteps // 10
    Dt = dt * res
    x = np.zeros((3, L2))
    
    for i in range(L2):
        x[:, i] = x_f[:, res*i]

    return x, Dt

timesteps = int(1e6)
dt = 0.03
res = 10
eps = 0.75

x, dt = potential_data(timesteps, dt, res, eps)

np.save('potentialwell.npy', x)
# Out:
# 100%|████████████████████████████████| 999999/999999 [01:08<00:00, 14553.18it/s]
# Done saving data for potential well.

# %%
import matplotlib.pyplot as plt

# Set up the loop and plot
fig =  plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[0,:], x[1,:], x[2,:], s=.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3d potential well')
plt.savefig('../../fig/3dPotentialWell.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 10
#       8 ax.set_ylabel('Y')
#       9 ax.set_zlabel('Z')
# ---> 10 ax.set_title('3d potential well'.format(ncenters, sil_avg))
#      11 plt.savefig('../../fig/3dPotentialWell.png')
#      12 plt.show()
#
# NameError: name 'ncenters' is not defined

# %%
xx = odeint(force, np.zeros(3), np.array([0, dt]))
xx
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])
